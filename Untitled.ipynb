# %%
import pandas as pd

# %%
#df = pd.read_excel (r'INSCRITOS_OFI.xlsx')
resumen = pd.read_excel (r'tabla_contactos_resumen.xlsx')
resumen
# Out:
#        Unnamed: 0     id   contacto     tipo  nro_programas  programas  \
# 0               0  31090  916670916  celular              1    olx2019
# 1               1  33417  927132526  celular              1    olx2019
# 2               2  33416  927124931  celular              1    olx2019
# 3               3  33415  927123602  celular              1    olx2019
# 4               4  33414  927122427  celular              1    olx2019
# ...           ...    ...        ...      ...            ...        ...
# 60357       60357  56604  999208248  celular              1  renta1ra2
# 60358       60358  56603  999207978  celular              1  renta1ra2
# 60359       60359  56602  999190331  celular              1  renta1ra2
# 60360       60360  56582  999022804  celular              1  renta1ra2
# 60361       60361  55416  946122457  celular              1  renta1ra2
#
#       control_programas  flag_control programa_control  flag_formal  \
# ...

# %%
#df = pd.read_excel (r'INSCRITOS_OFI.xlsx')
pad_magna = pd.read_excel (r'pad_magna.xlsx')
pad_magna
# Out:
#            num_ruc telefono1 telefono2  telefono3 telefono4  \
# 0      20604591831         -         -  950814323         -
# 1      10404116717         -         -  993050402         -
# 2      10253130216         -         -  999999999         -
# 3      20562782495         -         -  991353943         -
# 4      10475895865         -         -  993777213         -
# ...            ...       ...       ...        ...       ...
# 69250  10104481740         -         -  979473837         -
# 69251  10243861778         -         -  999999999         -
# 69252  15603278698         -         -  932084879         -
# 69253  10473256482         -         -  941915835         -
# 69254  10432144815         -         -  953396432         -
#
#                                correo1 correo2         dni   fec_react  \
# 0             march_harold@hotmail.com       -         NaN  2019/04/22
# 1           danielserrano.om@gmail.com       -  40411671.0  2000/11/27
# ...

# %%
rucs = pd.read_csv (r'MATCH_PAD_CONTRI_CU_MAGNA3.csv',sep=';')
rucs
# Out:
#           num_ruc telefono1 telefono2  telefono3  telefono4  \
# 0     10085461554         -         -  947107437  985636411
# 1     10073180100         -         -  994940994  989281910
# 2     10736560254         -         -  930519993          -
# 3     20603336853         -         -  997693272          -
# 4     20606618213         -         -  946049473  970703329
# ...           ...       ...       ...        ...        ...
# 3941  10104481740         -         -  979473837          -
# 3942  10243861778         -         -  999999999          -
# 3943  15603278698         -         -  932084879          -
# 3944  10473256482         -         -  941915835          -
# 3945  10432144815         -         -  953396432          -
#
#                             correo1                    correo2         dni  \
# 0      barbara.alarcon.rf@gmail.com                          -   8546155.0
# 1                baumi400@gmail.com           j19m35@gmail.com   7318010.0
# ...

# %%
resumen = resumen.set_index('contacto')
rucs = rucs.set_index('telefono3')

if resumen['contacto'] == 'Value': 
    df['c2'] = 10 
else: 
    df['c2'] = df['c3']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-6dff62feaee2> in <module>
# ----> 1 resumen = resumen.set_index('contacto')
#       2 rucs = rucs.set_index('telefono3')
#       3
#       4 varr = pd.merge(resumen, rucs, left_on="contacto", right_on="telefono3")
#       5 varr
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['contacto'] are in the columns"
